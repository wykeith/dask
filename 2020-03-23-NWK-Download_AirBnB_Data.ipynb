data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 October, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-10-25/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 October, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-10-25/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 October, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-10-25/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 October, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-10-25/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-10-25/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-10-25/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 September, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-09-25/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 September, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-09-25/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 September, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-09-25/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 September, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-09-25/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 September, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-09-25/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-09-25/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-09-25/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>28 August, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-08-28/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>28 August, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-08-28/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>28 August, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-08-28/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>28 August, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-08-28/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>28 August, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-08-28/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-08-28/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-08-28/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>21 July, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-07-21/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>21 July, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-07-21/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>21 July, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-07-21/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>21 July, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-07-21/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>21 July, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-07-21/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-07-21/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-07-21/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 June, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-06-25/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 June, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-06-25/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 June, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-06-25/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 June, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-06-25/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>25 June, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-06-25/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-06-25/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-06-25/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>23 May, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-05-23/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>23 May, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-05-23/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>23 May, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-05-23/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>23 May, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-05-23/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>23 May, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-05-23/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-05-23/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-05-23/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>20 April, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-04-20/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>20 April, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-04-20/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>20 April, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-04-20/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>20 April, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-04-20/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>20 April, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-04-20/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-04-20/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-04-20/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>18 March, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-03-18/data/listings.csv.gz" onclick="var that=this;ga('send','event', 'download','listings',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv.gz</a></td>
                <td>Detailed Listings data for Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>18 March, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-03-18/data/calendar.csv.gz" onclick="var that=this;ga('send','event', 'download','calendar',this.href);setTimeout(function(){location.href=that.href;},200);return false;">calendar.csv.gz</a></td>
                <td>Detailed Calendar Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>18 March, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-03-18/data/reviews.csv.gz" onclick="var that=this;ga('send','event', 'download','reviews',this.href);setTimeout(function(){location.href=that.href;},200);return false;">reviews.csv.gz</a></td>
                <td>Detailed Review Data for listings in Singapore</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>18 March, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-03-18/visualisations/listings.csv" onclick="var that=this;ga('send','event', 'download','listings_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;">listings.csv</a></td>
                <td>Summary information and metrics for listings in Singapore (good for visualisations).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>18 March, 2019</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-03-18/visualisations/reviews.csv" onclick="var that=this;ga('send','event', 'download','reviews_visualisation',this.href);setTimeout(function(){location.href=that.href;},200);return false;"> reviews.csv</a></td>
                <td>Summary Review data and Listing ID (to facilitate time based analytics and visualisations linked to a listing).</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-03-18/visualisations/neighbourhoods.csv" onclick="var that=this;ga('send','event', 'download','neighbourhoods',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.csv</a></td>
                <td>Neighbourhood list for geo filter. Sourced from city or open source GIS files.</td>
            </tr>
            <tr class="archived" style="display: table-row;">
                <td>N/A</td>
                <td>Singapore</td>
                <td><a href="http://data.insideairbnb.com/singapore/sg/singapore/2019-03-18/visualisations/neighbourhoods.geojson" onclick="var that=this;ga('send','event', 'download','geojson',this.href);setTimeout(function(){location.href=that.href;},200);return false;">neighbourhoods.geojson</a></td>
                <td>GeoJSON file of neighbourhoods of the city.</td>
            </tr>
       </tbody>
'''

# %%
soup = BeautifulSoup(html,'html.parser')
urls = []
dirnames = []
for tag in soup.find_all('a'):
    urls.append(tag.get('href'))
    dirnames.append(os.path.join(str.split(tag.get('href'),'/')[-4],str.split(tag.get('href'),'/')[-3]))

# %%
for url,dirname in zip(urls,dirnames):
    if not os.path.exists(dirname):
        os.makedirs(dirname)
    urllib.urlretrieve(url, os.path.join(dirname,os.path.basename(url)))
